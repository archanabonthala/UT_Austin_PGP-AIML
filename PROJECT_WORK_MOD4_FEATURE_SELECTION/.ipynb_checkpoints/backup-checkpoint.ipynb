# %% [markdown]
# # Problem Statement
#
# Customers’ leaving credit cards services would lead bank to loss, so the bank wants to analyze the data of customers’ and identify the customers who will leave their credit card services and reason for same – so that bank could improve upon those areas
#
# You as a Data scientist at Thera bank need to come up with a classification model that will help bank improve their services so that customers do not renounce their credit cards

# %% [markdown]
# # Data Dictionary:
#
#
# * CLIENTNUM: Client number. Unique identifier for the customer holding the account
# * Attrition_Flag: Internal event (customer activity) variable - if the account is closed then 1 else 0
# * Customer_Age: Age in Years
# * Gender: Gender of the account holder
# * Dependent_count: Number of dependents
# * Education_Level: Educational Qualification of the account holder
# * Marital_Status: Marital Status of the account holder
# * Income_Category: Annual Income Category of the account holder
# * Card_Category: Type of Card
# * Months_on_book: Period of relationship with the bank
# * Total_Relationship_Count: Total no. of products held by the customer
# * Months_Inactive_12_mon: No. of months inactive in the last 12 months
# * Contacts_Count_12_mon: No. of Contacts in the last 12 months
# * Credit_Limit: Credit Limit on the Credit Card
# * Total_Revolving_Bal: Total Revolving Balance on the Credit Card
# * Avg_Open_To_Buy: Open to Buy Credit Line (Average of last 12 months)
# * Total_Amt_Chng_Q4_Q1: Change in Transaction Amount (Q4 over Q1)
# * Total_Trans_Amt: Total Transaction Amount (Last 12 months)
# * Total_Trans_Ct: Total Transaction Count (Last 12 months)
# * Total_Ct_Chng_Q4_Q1: Change in Transaction Count (Q4 over Q1)
# * Avg_Utilization_Ratio: Average Card Utilization Ratio

# %% [markdown]
# ###  Import Libraries

# %%
import warnings

warnings.filterwarnings("ignore")

# Libraries for reading and manipulating data
import pandas as pd
import numpy as np

# libaries for data visualization
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# Libraries to tune model, get different metric scores, and split data
from sklearn import metrics
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

from sklearn.impute import KNNImputer
from sklearn.pipeline import Pipeline, make_pipeline

#libraries for model building
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    AdaBoostClassifier,
    GradientBoostingClassifier,
    RandomForestClassifier)

# %%
#place holder to import XGBoost

# %%
data = pd.read_csv('BankChurners.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %% [markdown]
# * No NULL Values in any columns(no missing data)
# * There are 21 columns and 10127 rows

# %%
data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
data.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %% [markdown]
# * Customer age range is 26 - 73 years.
# * Maximum period Customers stayed with bank is 56 years.
#   Minimun period Customers stayed with bank is 13 years.

# %%
data.columns[data.dtypes=='object']
# Out:
# Index(['Attrition_Flag', 'Gender', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category'],
#       dtype='object')

# %%
category_col = ['Attrition_Flag', 'Gender', 'Education_Level', 'Marital_Status',
       'Income_Category', 'Card_Category']
for col in category_col:
    print('---------------------------------')
    print(data[col].value_counts())
    print('---------------------------------')
# Out:
# ---------------------------------
# Existing Customer    8500
# Attrited Customer    1627
# Name: Attrition_Flag, dtype: int64
# ---------------------------------
# ---------------------------------
# F    5358
# M    4769
# Name: Gender, dtype: int64
# ---------------------------------
# ---------------------------------
# Graduate         3128
# High School      2013
# Unknown          1519
# Uneducated       1487
# College          1013
# Post-Graduate     516
# Doctorate         451
# Name: Education_Level, dtype: int64
# ---------------------------------
# ---------------------------------
# Married     4687
# Single      3943
# Unknown      749
# Divorced     748
# Name: Marital_Status, dtype: int64
# ---------------------------------
# ---------------------------------
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# Unknown           1112
# $120K +            727
# Name: Income_Category, dtype: int64
# ...

# %%
data.isnull().sum()
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %% [markdown]
# # EDA

# %% [markdown]
# ### Univariant Analysis

# %%
# for Univariant Analysis of Numerical columns,  Boxplot and histograms are plotted.
# Histogram is used to study distribution and central tendency.
# Boxplot is used to understand the outliers and quantiles.

def boxplot_histogram(feature, figsize=(15,10), bins=None):
    '''plots boxplot and histogram for given feature
    feature: 1-d feature array
    figsize: size of the figure
    bins: No of bins deault:None/auto'''
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.distplot(
        feature, kde=F, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.distplot(
        feature, kde=True, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        np.mean(feature), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        np.median(feature), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
# print all column names of datatype integer

for feature in data.iloc[:,1:].columns:
    if(data[feature].dtypes=='int64'):
        print(feature)   
        
print('--------------------------------')
for feature in data.iloc[:,1:].columns:
    if(data[feature].dtypes=='float64'):
        print(feature)
# Out:
# Customer_Age
# Dependent_count
# Months_on_book
# Total_Relationship_Count
# Months_Inactive_12_mon
# Contacts_Count_12_mon
# Total_Revolving_Bal
# Total_Trans_Amt
# Total_Trans_Ct
# --------------------------------
# Credit_Limit
# Avg_Open_To_Buy
# Total_Amt_Chng_Q4_Q1
# Total_Ct_Chng_Q4_Q1
# Avg_Utilization_Ratio

# %%
boxplot_histogram(data['Customer_Age'])

# %% [markdown]
# *  Customer age has fairly normal distribution with approx same mean and median.
# *  There are two outliers shown in the boxplots.

# %%
boxplot_histogram(data['Dependent_count'])

# %% [markdown]
# * There are more number of customers whoc have dependent count as 3.
#   Number of customers with Dependent_count= 2 is also approx same as Dependent_count= 3

# %%
boxplot_histogram(data['Months_on_book'])

# %% [markdown]
# * There are more number of customers around median and mean of Months_on_book
# * There are few outliers both on left and right.

# %%
boxplot_histogram(data['Total_Relationship_Count'])

# %% [markdown]
# Total_Relationship_Count: Total no. of products held by the customer
#
# Number of Customer with 3 products are more.

# %%
boxplot_histogram(data['Months_Inactive_12_mon'])

# %% [markdown]
# * Max number of users with  Months_inactive_12_mon is 3 months.

# %%
boxplot_histogram(data['Contacts_Count_12_mon'])

# %% [markdown]
# * Majority of customers contacted 2-3 times in last 12 months.

# %%
boxplot_histogram(data['Total_Revolving_Bal'])

# %% [markdown]
# * Most of the customers have total_revolving_bal as zero.

# %%
boxplot_histogram(data['Total_Trans_Amt'])

# %% [markdown]
# * There are many outliers in Total_Trans_Amt but these outliers cannot be removed or modified as we want the model to learn from these datapoints.

# %%
boxplot_histogram(data['Total_Trans_Ct'])

# %% [markdown]
# * Number of transactions distribution has two peaks one around 40 and other around 80.
# * There are two outliers on right but they are not very far from quantile so looks like they are valid points.

# %%
boxplot_histogram(data['Credit_Limit'])

# %% [markdown]
# * Credit limit is left skewed.
# * Many outliers to the right.

# %%
boxplot_histogram(data['Avg_Open_To_Buy'])

# %% [markdown]
# * Avg_Open_To_Buy is left skewed.
# * Many outliers to the right.

# %%
boxplot_histogram(data['Total_Amt_Chng_Q4_Q1'])

# %% [markdown]
# * Outliers are towards right and left. two datapoints which are to the extreme right greater than 3.5 can be clipped off to 3.0

# %%
boxplot_histogram(data['Total_Ct_Chng_Q4_Q1'])

# %%
boxplot_histogram(data['Avg_Utilization_Ratio'])

# %% [markdown]
# ### Overall Insights from Numeric columns Univariant graphs
#
# *  The outliers in the numeric columns donot look very abnormal. So the outliers are retained with out any imputation.
# *  Customer age has fairly normal distribution with approx same mean and median.
# * Credit limit, Avg_Open_To_Buy are left skewed.
# * Total_Ct_Chng_Q4_Q1 and Total_Amt_Chng_Q4_Q1 have same distribution pattern.

# %%
# Generate counts plot graphs for categorical features in the data.
def count_plots(feature):
    '''Plots count_plot for category variables
    feature: 1-d feature array'''
    plt.figure(figsize=(10,5))
    ax = sns.countplot(feature)
    total = len(feature)  # length of the column
    for p in ax.patches:
        percentage = "{:.1f}%".format(
            100 * p.get_height() / total
        )  # percentage of each class of the category
        x = p.get_x() + p.get_width() / 2 - 0.1  # width of the plot
        y = p.get_y() + p.get_height()  # hieght of the plot
        ax.annotate(percentage, (x, y), size=14)  # annotate the percantage

    plt.show()  # show the plot

# %%
# print all column names of datatype object
for feature in data.iloc[:,1:].columns:
    if(data[feature].dtypes=='object'):
        print(feature)
# Out:
# Attrition_Flag
# Gender
# Education_Level
# Marital_Status
# Income_Category
# Card_Category

# %%
count_plots(data['Attrition_Flag'])

# %%
count_plots(data['Gender'])

# %%
count_plots(data['Education_Level'])

# %%
count_plots(data['Marital_Status'])

# %%
count_plots(data['Income_Category'])

# %%
count_plots(data['Card_Category'])

# %% [markdown]
# ### Insights from Count plots
#
# * 16% of Customers left their credit card services.
# * Female customers are more.
# * Majority of customers are graduates, Married.
# * Popular income category is less than 40k.
# * Blue type card is famous among the Card_categories.

# %% [markdown]
# ### Bivariant Analysis

# %%
sns.set(rc={"figure.figsize": (10, 7)})
sns.boxplot(y="Total_Trans_Amt", x="Income_Category", data=data, orient="vertical")

# %%
sns.set(rc={"figure.figsize": (10, 7)})
sns.boxplot(y="Total_Trans_Amt", x="Education_Level", data=data, orient="vertical")

# %%
sns.set(rc={"figure.figsize": (10, 7)})
sns.boxplot(y="Total_Trans_Amt", x="Dependent_count", data=data, orient="vertical")

# %%
sns.set(rc={"figure.figsize": (10, 7)})
sns.boxplot(y="Credit_Limit", x="Card_Category", data=data, orient="vertical")

# %%
sns.set(rc={"figure.figsize": (10, 7)})
sns.boxplot(y="Total_Trans_Amt", x="Card_Category", data=data, orient="vertical")

# %%
sns.regplot(y=data.Total_Trans_Amt, x=data.Customer_Age)
#Customer_Age,Credit_Limit

# %%
sns.regplot(y=data.Credit_Limit, x=data.Total_Trans_Amt)

# %%
### Function to plot stacked bar charts for categorical columns
def stacked_plot(x):
    sns.set(palette="nipy_spectral")
    tab1 = pd.crosstab(x, data["Attrition_Flag"], margins=True)
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(x, data["Attrition_Flag"], normalize="index")
    tab.plot(kind="bar", stacked=True, figsize=(10, 5))
    plt.legend(loc="lower left", frameon=False)
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

# %%
stacked_plot(data['Education_Level'])
# Out:
# Attrition_Flag   Attrited Customer  Existing Customer    All
# Education_Level
# College                        154                859   1013
# Doctorate                       95                356    451
# Graduate                       487               2641   3128
# High School                    306               1707   2013
# Post-Graduate                   92                424    516
# Uneducated                     237               1250   1487
# Unknown                        256               1263   1519
# All                           1627               8500  10127
# ------------------------------------------------------------------------------------------------------------------------

# %%
stacked_plot(data['Income_Category'])
# Out:
# Attrition_Flag   Attrited Customer  Existing Customer    All
# Income_Category
# $120K +                        126                601    727
# $40K - $60K                    271               1519   1790
# $60K - $80K                    189               1213   1402
# $80K - $120K                   242               1293   1535
# Less than $40K                 612               2949   3561
# Unknown                        187                925   1112
# All                           1627               8500  10127
# ------------------------------------------------------------------------------------------------------------------------

# %%
stacked_plot(data['Card_Category'])
# Out:
# Attrition_Flag  Attrited Customer  Existing Customer    All
# Card_Category
# Blue                         1519               7917   9436
# Gold                           21                 95    116
# Platinum                        5                 15     20
# Silver                         82                473    555
# All                          1627               8500  10127
# ------------------------------------------------------------------------------------------------------------------------

# %%
stacked_plot(data['Dependent_count'])
# Out:
# Attrition_Flag   Attrited Customer  Existing Customer    All
# Dependent_count
# 0                              135                769    904
# 1                              269               1569   1838
# 2                              417               2238   2655
# 3                              482               2250   2732
# 4                              260               1314   1574
# 5                               64                360    424
# All                           1627               8500  10127
# ------------------------------------------------------------------------------------------------------------------------

# %%
sns.set(rc={"figure.figsize": (15, 15)})
sns.heatmap(
    data.corr(),
    annot=True,
    linewidths=0.5,
    center=0,
    cbar=False,
    cmap="YlGnBu",
    fmt="0.2f",
)
plt.show()

# %% [markdown]
# ###  Illustrate the insights based on EDA

# %% [markdown]
# * There is huge difference in the credit limit based on card_category.
# Platinum card has higher credit limit.
#
# * Platinum Card holder have Higher transaction Amount
#   Blue card holders have minimum transaction Amount but with few outlier on the higher end.
#     There is clear relation ship between Transaction_Amount and Card_Category.
#
# * Total_Ct_Chng_Q4_Q1 and Total_Amt_Chng_Q4_Q1 have same distribution pattern.
#
# * Attrition customers are more in Doctorates.
#
# * Attrition is almost similar in all Income_categories.
#
# * Attrition is more in Platinum card category.
#
# * Attrition is slightly more in Dependent_count =3.
#
# * There is good correlation between Total_Trans_amt and Total_trans_Ct.
#     One column can be removed due to multiple corrlation problem.

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ###  Missing Values
#
# There are no null values in any of the columns.
#
#
# ###  Outliers
#
# Outliers in the columns donot look very abnormal.
# Not removing outliers from the data so that models learns from the data points.
#
#
#
#
# ### Feature Engineering

# %% [markdown]
# ###  One_hot Encoding
#
# replaceStruct = {
#                 "Attrition_Flag" : {"Attrited Customer" }
#                 "checking_balance":     {"< 0 DM": 1, "1 - 200 DM": 2 ,"> 200 DM": 3 ,"unknown":-1},
#                 "credit_history": {"critical": 1, "poor":2 , "good": 3, "very good": 4,"perfect": 5},
#                  "savings_balance": {"< 100 DM": 1, "100 - 500 DM":2 , "500 - 1000 DM": 3, "> 1000 DM": 4,"unknown": -1},
#                  "employment_duration":     {"unemployed": 1, "< 1 year": 2 ,"1 - 4 years": 3 ,"4 - 7 years": 4 ,"> 7 years": 5},
#                 "phone":     {"no": 1, "yes": 2 },
#                 #"job":     {"unemployed": 1, "unskilled": 2, "skilled": 3, "management": 4 },
#                 "default":     {"no": 0, "yes": 1 }
#                     }
# oneHotCols=["purpose","housing","other_credit","job"]

# %%
for feature in data.columns: # Loop through all columns in the dataframe
    if data[feature].dtype == 'object': # Only apply for columns with categorical strings
        data[feature] = pd.Categorical(data[feature])# Replace strings with an integer
data.head(10)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
# 5  713061558  Existing Customer            44      M                2
# 6  810347208  Existing Customer            51      M                4
# 7  818906208  Existing Customer            32      M                0
# 8  710930508  Existing Customer            37      M                3
# 9  719661558  Existing Customer            48      M                2
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# ...

# %%
data.dtypes
# Out:
# CLIENTNUM                      int64
# Attrition_Flag              category
# Customer_Age                   int64
# Gender                      category
# Dependent_count                int64
# Education_Level             category
# Marital_Status              category
# Income_Category             category
# Card_Category               category
# Months_on_book                 int64
# Total_Relationship_Count       int64
# Months_Inactive_12_mon         int64
# Contacts_Count_12_mon          int64
# Credit_Limit                 float64
# Total_Revolving_Bal            int64
# Avg_Open_To_Buy              float64
# Total_Amt_Chng_Q4_Q1         float64
# Total_Trans_Amt                int64
# Total_Trans_Ct                 int64
# Total_Ct_Chng_Q4_Q1          float64
# Avg_Utilization_Ratio        float64
# dtype: object
