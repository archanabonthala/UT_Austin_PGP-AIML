# %%
# Plotting all the subplots
fig, axes = plt.subplots(2, 3)

axes[0, 0].plot(tourismDf_Basic['Age'])

# %%
import matplotlib.gridspec as GridSpec

# Setting up the plot surface
fig = plt.figure(figsize=(10, 5))
gs = GridSpec(nrows=2, ncols=3)


# First axes
ax0 = fig.add_subplot(gs[0, 0])
ax0.plot(tourismDf_Basic['Age'])

# %%
import matplotlib.pyplot as plt
from matplotlib import gridspec


fig = plt.figure(figsize=(15, 10))
gs = gridspec.GridSpec(2, 3)

ax1 = fig.add_subplot(gs[0, 0])
ax1.plot(tourismDf_Basic['Age'])

ax2 = fig.add_subplot(gs[0, 1])
ax2.plot(x,y)

ax1 = fig.add_subplot(gs[0, 2])
ax1.plot(x, y)

ax2 = fig.add_subplot(gs[1, 0])
ax2.plot(x,y)

ax1 = fig.add_subplot(gs[1, 1])
ax1.plot(x, y)

ax2 = fig.add_subplot(gs[1, 2])
ax2.plot(x,y)

plt.show()

# %%
tourismDf_Basic = tourismDf[tourismDf['ProductPitched']=='Basic']
tot = len(tourismDf_Basic)

fig, ax_list = plt.subplots(3, 3, figsize=(20,20))

g1 = sns.distplot(tourismDf_Basic['Age'], ax=ax_list[0,0]) 

g2 = sns.countplot(tourismDf_Basic['Occupation'], ax=ax_list[0,1]) 
for p in g2.patches:
    g2.annotate(format((p.get_height()/tot)*100, '.2f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')

g3 = sns.countplot(tourismDf_Basic['MaritalStatus'], ax=ax_list[0,2])
for p in g3.patches:
    g3.annotate(format((p.get_height()/tot)*100, '.2f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')

g4 = sns.countplot(tourismDf_Basic['Designation'], ax=ax_list[1,0])
for p in g4.patches:
    g4.annotate(format((p.get_height()/tot)*100, '.2f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
 
g5 = sns.distplot(tourismDf_Basic['MonthlyIncome'], ax=ax_list[1,1]) 


g6 = sns.countplot(tourismDf_Basic['Gender'], ax=ax_list[1,2]) 
for p in g6.patches:
    g6.annotate(format((p.get_height()/tot)*100, '.2f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')


g7 = sns.countplot(tourismDf_Basic['OwnCar'], ax=ax_list[2,0])
for p in g7.patches:
    g7.annotate(format((p.get_height()/tot)*100, '.2f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
    

g8 = sns.countplot(tourismDf_Basic['Passport'], ax=ax_list[2,1]) 
for p in g8.patches:
    g8.annotate(format((p.get_height()/tot)*100, '.2f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')

g9 = sns.countplot(tourismDf_Basic['ProdTaken'], ax=ax_list[2,2])
for p in g9.patches:
    g9.annotate(format((p.get_height()/tot)*100, '.2f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')

plt.show()
